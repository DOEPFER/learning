# %% [markdown]
# ### Import

# %%
import numpy as np
import pandas as pd

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load

# %%
dataframe_penguins = sns.load_dataset('penguins')

# %% [markdown]
# ### Preview

# %%
dataframe_penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
dataframe_penguins.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
# dataframe_penguins.select_dtypes(include='number').columns.values

# %%
dataframe_penguins.dropna(subset=['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g'], inplace=True)

# %%
dataframe_penguins.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  9
# dtype: int64

# %%
dataframe_penguins_numeric = dataframe_penguins.select_dtypes(include='number')
dataframe_penguins_numeric.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1           18.7              181.0       3750.0
# 1            39.5           17.4              186.0       3800.0
# 2            40.3           18.0              195.0       3250.0
# 4            36.7           19.3              193.0       3450.0
# 5            39.3           20.6              190.0       3650.0

# %% [markdown]
# ### Preclustering

# %% [markdown]
# #### Features

# %% [markdown]
# ##### _bin

# %% [markdown]
# bill_length_mm

# %%
ndigits = -1
dataframe_penguins['bill_length_mm_bin'] = round(dataframe_penguins['bill_length_mm'], ndigits=ndigits)

print(f"{dataframe_penguins['bill_length_mm'].head(3).values} \n{round(dataframe_penguins['bill_length_mm'], ndigits=ndigits).head(3).values}")
print(f"from {len(dataframe_penguins['bill_length_mm'].unique())} | to {len(dataframe_penguins['bill_length_mm_bin'].unique())}")
print(sorted(dataframe_penguins['bill_length_mm_bin'].unique()))
# Out:
# [39.1 39.5 40.3]
# [40. 40. 40.]
# from 164 | to 4
# [np.float64(30.0), np.float64(40.0), np.float64(50.0), np.float64(60.0)]

# %% [markdown]
# bill_depth_mm

# %%
ndigits = -1
dataframe_penguins['bill_depth_mm_bin'] = round(dataframe_penguins['bill_depth_mm'], ndigits=ndigits)

print(f"{dataframe_penguins['bill_depth_mm'].head(3).values} \n{round(dataframe_penguins['bill_depth_mm'], ndigits=ndigits).head(3).values}")
print(f"from {len(dataframe_penguins['bill_depth_mm'].unique())} | to {len(dataframe_penguins['bill_depth_mm_bin'].unique())}")
print(sorted(dataframe_penguins['bill_depth_mm_bin'].unique()))
# Out:
# [18.7 17.4 18. ]
# [20. 20. 20.]
# from 80 | to 2
# [np.float64(10.0), np.float64(20.0)]

# %% [markdown]
# flipper_length_mm

# %%
ndigits = -1
dataframe_penguins['flipper_length_mm_bin'] = round(dataframe_penguins['flipper_length_mm'], ndigits=ndigits)

print(f"{dataframe_penguins['flipper_length_mm'].head(3).values} \n{round(dataframe_penguins['flipper_length_mm'], ndigits=ndigits).head(3).values}")
print(f"from {len(dataframe_penguins['flipper_length_mm'].unique())} | to {len(dataframe_penguins['flipper_length_mm_bin'].unique())}")
print(sorted(dataframe_penguins['flipper_length_mm_bin'].unique()))
# Out:
# [181. 186. 195.]
# [180. 190. 200.]
# from 55 | to 7
# [np.float64(170.0), np.float64(180.0), np.float64(190.0), np.float64(200.0), np.float64(210.0), np.float64(220.0), np.float64(230.0)]

# %% [markdown]
# body_mass_g

# %%
ndigits = -3
dataframe_penguins['body_mass_g_bin'] = round(dataframe_penguins['body_mass_g'], ndigits=ndigits)

print(f"{dataframe_penguins['body_mass_g'].head(3).values} \n{round(dataframe_penguins['body_mass_g'], ndigits=ndigits).head(3).values}")
print(f"from {len(dataframe_penguins['body_mass_g'].unique())} | to {len(dataframe_penguins['body_mass_g_bin'].unique())}")
print(sorted(dataframe_penguins['body_mass_g_bin'].unique()))
# Out:
# [3750. 3800. 3250.]
# [4000. 4000. 3000.]
# from 94 | to 4
# [np.float64(3000.0), np.float64(4000.0), np.float64(5000.0), np.float64(6000.0)]

# %% [markdown]
# ##### _mean

# %%
dataframe_penguins[['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean']] = dataframe_penguins.groupby(by=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'])[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']].transform('mean')

# %% [markdown]
# #### Preclustering

# %% [markdown]
# ##### _bin

# %%
dataframe_penguins['cluster_bin'] = (
    dataframe_penguins['bill_length_mm_bin'].astype(str) + '_' + 
    dataframe_penguins['bill_depth_mm_bin'].astype(str) + '_' + 
    dataframe_penguins['flipper_length_mm_bin'].astype(str) + '_' + 
    dataframe_penguins['body_mass_g_bin'].astype(str)
)

len(dataframe_penguins['cluster_bin'].unique())
# Out:
# 46

# %%
# sns.pairplot(dataframe_penguins, hue='cluster_bin')

# %% [markdown]
# ##### _mean

# %%
dataframe_penguins['cluster_mean'] = (
    dataframe_penguins['bill_length_mm_bin_mean'].astype(str) + '_' + 
    dataframe_penguins['bill_depth_mm_bin_mean'].astype(str) + '_' + 
    dataframe_penguins['flipper_length_mm_bin_mean'].astype(str) + '_' + 
    dataframe_penguins['body_mass_g_bin_mean'].astype(str)
)

len(dataframe_penguins['cluster_mean'].unique())
# Out:
# 46

# %%
# sns.pairplot(dataframe_penguins, hue='cluster_mean')

# %% [markdown]
# ### K-means #1 | mean

# %% [markdown]
# - Utiliza a média das variáveis ('bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g') referente aos grupos criados no preclustring.
# - K-means aplicado a uma amostra.

# %% [markdown]
# #### Sample

# %%
dataframe_penguins_numeric_discrete_data = dataframe_penguins.drop_duplicates(subset=['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean'])[['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean']]

# %% [markdown]
# #### K-means

# %%
kmeans = KMeans(n_clusters=3, max_iter=600, n_init='auto', algorithm='lloyd')
kmeans.fit(dataframe_penguins_numeric_discrete_data)
# Out:
# KMeans(max_iter=600, n_clusters=3)

# %% [markdown]
# #### Cluster assign

# %%
dataframe_penguins_numeric_discrete_data['cluster_discrete_by_mean'] = kmeans.labels_.astype('str')

# %%
# dataframe_penguins_numeric_discrete_data

# %% [markdown]
# #### Assign sample cluster to data

# %%
dataframe_penguins = dataframe_penguins.merge(right=dataframe_penguins_numeric_discrete_data[['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean', 'cluster_discrete_by_mean']], on=['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean'], how='left')

# %%
# dataframe_penguins

# %% [markdown]
# #### Graph

# %%
dataframe_penguins_numeric_kmeans1 = dataframe_penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'cluster_discrete_by_mean']]

# %%
sns.pairplot(dataframe_penguins_numeric_kmeans1, hue='cluster_discrete_by_mean')

# %%
pd.crosstab(dataframe_penguins['species'], dataframe_penguins['cluster_discrete_by_mean'])
# Out:
# cluster_discrete_by_mean   0   1    2
# species
# Adelie                    37   0  114
# Chinstrap                 34   1   33
# Gentoo                    46  77    0

# %% [markdown]
# ### K-means #2 | bin

# %% [markdown]
# - Utiliza os valores arredondados (bins) das variáveis ('bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g') referente aos grupos criados no preclustring.
# - K-means aplicado a uma amostra.

# %% [markdown]
# #### Sample

# %%
dataframe_penguins_numeric_discrete_data = dataframe_penguins.drop_duplicates(subset=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'])[['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin']]

# %% [markdown]
# #### K-means

# %%
kmeans = KMeans(n_clusters=3, max_iter=600, n_init='auto', algorithm='lloyd')
kmeans.fit(dataframe_penguins_numeric_discrete_data)
# Out:
# KMeans(max_iter=600, n_clusters=3)

# %% [markdown]
# #### Cluster assign

# %%
dataframe_penguins_numeric_discrete_data['cluster_discrete_by_bin'] = kmeans.labels_.astype('str')

# %%
dataframe_penguins_numeric_discrete_data
# Out:
#      bill_length_mm_bin  bill_depth_mm_bin  flipper_length_mm_bin  \
# 0                  40.0               20.0                  180.0
# 1                  40.0               20.0                  190.0
# 2                  40.0               20.0                  200.0
# 3                  40.0               20.0                  190.0
# 6                  40.0               20.0                  200.0
# 7                  30.0               20.0                  190.0
# 11                 40.0               20.0                  180.0
# 13                 30.0               20.0                  200.0
# 16                 40.0               20.0                  200.0
# 17                 30.0               20.0                  180.0
# 18                 50.0               20.0                  190.0
# 19                 40.0               20.0                  170.0
# 38                 40.0               20.0                  180.0
# 44                 40.0               20.0                  190.0
# 69                 30.0               20.0                  190.0
# 72                 50.0               20.0                  200.0
# 94                 40.0               20.0                  210.0
# 110                50.0               20.0                  190.0
# 157                50.0               20.0                  180.0
# 163                50.0               20.0                  180.0
# 167                50.0               20.0                  200.0
# 168                60.0               20.0                  180.0
# 169                50.0               20.0                  190.0
# 180                50.0               20.0                  200.0
# 188                50.0               20.0                  210.0
# 191                50.0               20.0                  210.0
# 214                60.0               20.0                  210.0
# 219                50.0               10.0                  210.0
# 220                50.0               20.0                  230.0
# 222                50.0               20.0                  220.0
# 223                50.0               10.0                  220.0
# 224                50.0               10.0                  210.0
# 226                50.0               20.0                  220.0
# 227                40.0               10.0                  210.0
# 229                40.0               10.0                  210.0
# 232                50.0               10.0                  210.0
# 239                50.0               10.0                  220.0
# 243                40.0               10.0                  220.0
# 245                40.0               10.0                  220.0
# 252                60.0               20.0                  230.0
# 256                40.0               20.0                  220.0
# 310                50.0               20.0                  230.0
# 317                50.0               10.0                  200.0
# 328                50.0               20.0                  210.0
# 331                40.0               20.0                  210.0
# 333                50.0               10.0                  220.0
#
#      body_mass_g_bin cluster_discrete_by_bin
# 0             4000.0                       0
# 1             4000.0                       0
# 2             3000.0                       2
# 3             3000.0                       2
# 6             5000.0                       1
# 7             3000.0                       2
# 11            3000.0                       2
# 13            4000.0                       0
# 16            4000.0                       0
# 17            3000.0                       2
# 18            4000.0                       0
# 19            3000.0                       2
# 38            5000.0                       1
# 44            5000.0                       1
# 69            4000.0                       0
# 72            4000.0                       0
# 94            4000.0                       0
# 110           5000.0                       1
# 157           3000.0                       2
# 163           4000.0                       0
# 167           3000.0                       2
# 168           4000.0                       0
# 169           3000.0                       2
# 180           5000.0                       1
# 188           5000.0                       1
# 191           4000.0                       0
# 214           4000.0                       0
# 219           4000.0                       0
# 220           6000.0                       1
# 222           6000.0                       1
# 223           5000.0                       1
# 224           5000.0                       1
# 226           5000.0                       1
# 227           4000.0                       0
# 229           5000.0                       1
# 232           6000.0                       1
# 239           6000.0                       1
# 243           5000.0                       1
# 245           4000.0                       0
# 252           6000.0                       1
# 256           5000.0                       1
# 310           5000.0                       1
# 317           5000.0                       1
# 328           6000.0                       1
# 331           5000.0                       1
# 333           4000.0                       0

# %% [markdown]
# #### Assign sample cluster to data

# %%
dataframe_penguins = dataframe_penguins.merge(right=dataframe_penguins_numeric_discrete_data[['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin', 'cluster_discrete_by_bin']], on=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'], how='left')

# %% [markdown]
# #### Graph

# %%
dataframe_penguins_numeric_kmeans2 = dataframe_penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'cluster_discrete_by_bin']]

# %%
sns.pairplot(dataframe_penguins_numeric_kmeans2, hue='cluster_discrete_by_bin')

# %%
pd.crosstab(dataframe_penguins['species'], dataframe_penguins['cluster_discrete_by_bin'])
# Out:
# cluster_discrete_by_bin   0    1   2
# species
# Adelie                   90    7  54
# Chinstrap                49    2  17
# Gentoo                   17  106   0

# %% [markdown]
# ### K-means #3 | mean scaled

# %% [markdown]
# - Utiliza a média das variáveis redimensionadas ('bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g') referente aos grupos criados no preclustring.
# - K-means aplicado a uma amostra.

# %% [markdown]
# #### Sample

# %%
dataframe_penguins_numeric_discrete_data = dataframe_penguins.drop_duplicates(subset=['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean'])[['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean']]

# %% [markdown]
# #### Data scaling

# %%
scaler = StandardScaler()
# scaler = MinMaxScaler()

dataframe_penguins_numeric_discrete_data_scaled = scaler.fit_transform(dataframe_penguins_numeric_discrete_data)

# %% [markdown]
# #### Elbow method

# %%
ssd = []
n_clusters = range(1, 15)

for n_clusters_ in n_clusters:
    kmeans = KMeans(n_clusters=n_clusters_, max_iter=600, n_init='auto', algorithm='lloyd')
    kmeans = kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)
    ssd.append(kmeans.inertia_)

# %%
elbow_dataframe = pd.DataFrame({'n_clusters': list(range(1, len(ssd) + 1)), 'SSD': ssd})
elbow_dataframe.plot(x = 'n_clusters', y = 'SSD')
# Out:
# <Axes: xlabel='n_clusters'>

# %% [markdown]
# #### Silhouette coefficient

# %%
silhouettes = []
max_clusters = 15
n_clusters = range(2, max_clusters + 1)

for n_clusters_ in n_clusters:
    kmeans = KMeans(n_clusters=n_clusters_, max_iter=600, n_init='auto', algorithm='lloyd')
    kmeans = kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)

    silhouette_coefficient = silhouette_score(dataframe_penguins_numeric_discrete_data_scaled, kmeans.labels_)
    silhouettes.append(silhouette_coefficient)

    cluster_names = [f'cluster_{cluster}' for cluster in range(n_clusters_)]
    dataframe_penguins_numeric_discrete_data[f'clusters_{n_clusters_}'] = pd.Categorical.from_codes(kmeans.labels_, categories=cluster_names)

# %%
silhouette_dataframe = pd.DataFrame({'number_clusters': list(n_clusters), 'mean_silhouette': silhouettes})
silhouette_dataframe.plot.line(x = 'number_clusters', y = 'mean_silhouette', marker='o')
# Out:
# <Axes: xlabel='number_clusters'>

# %% [markdown]
# #### K-means

# %%
kmeans = KMeans(n_clusters=3, max_iter=600, n_init='auto', algorithm='lloyd')
kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)
# Out:
# KMeans(max_iter=600, n_clusters=3)

# %% [markdown]
# #### Cluster assign

# %%
dataframe_penguins_numeric_discrete_data['cluster_discrete_by_mean_scaled'] = kmeans.labels_.astype('str')

# %%
# dataframe_penguins_numeric_discrete_data

# %% [markdown]
# #### Assign sample cluster to data

# %%
dataframe_penguins = dataframe_penguins.merge(right=dataframe_penguins_numeric_discrete_data[['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean', 'cluster_discrete_by_mean_scaled']], on=['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean'], how='left')

# %% [markdown]
# #### Graph

# %%
dataframe_penguins_numeric_kmeans3 = dataframe_penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'cluster_discrete_by_mean_scaled']]

# %%
sns.pairplot(dataframe_penguins_numeric_kmeans3, hue='cluster_discrete_by_mean_scaled')

# %%
pd.crosstab(dataframe_penguins['species'], dataframe_penguins['cluster_discrete_by_mean_scaled'])
# Out:
# cluster_discrete_by_mean_scaled   0    1   2
# species
# Adelie                            0  151   0
# Chinstrap                         0   67   1
# Gentoo                           59    0  64

# %% [markdown]
# ### K-means #4 | bin scaled

# %% [markdown]
# - Utiliza os valores arredondados (bins) das variáveis redimensionados ('bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g') referente aos grupos criados no preclustring.
# - K-means aplicado a uma amostra.

# %% [markdown]
# #### Sample

# %%
dataframe_penguins_numeric_discrete_data = dataframe_penguins.drop_duplicates(subset=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'])[['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin']]

# %% [markdown]
# #### Data scaling

# %%
# scaler = StandardScaler()
scaler = MinMaxScaler()

dataframe_penguins_numeric_discrete_data_scaled = scaler.fit_transform(dataframe_penguins_numeric_discrete_data)

# %% [markdown]
# #### Elbow method

# %%
ssd = []
n_clusters = range(1, 15)

for n_clusters_ in n_clusters:
    kmeans = KMeans(n_clusters=n_clusters_, max_iter=600, n_init='auto', algorithm='lloyd')
    kmeans = kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)
    ssd.append(kmeans.inertia_)

# %%
elbow_dataframe = pd.DataFrame({'n_clusters': list(range(1, len(ssd) + 1)), 'SSD': ssd})
elbow_dataframe.plot(x = 'n_clusters', y = 'SSD')
# Out:
# <Axes: xlabel='n_clusters'>

# %% [markdown]
# #### Silhouette coefficient

# %%
silhouettes = []
max_clusters = 15
n_clusters = range(2, max_clusters + 1)

for n_clusters_ in n_clusters:
    kmeans = KMeans(n_clusters=n_clusters_, max_iter=600, n_init='auto', algorithm='lloyd')
    kmeans = kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)

    silhouette_coefficient = silhouette_score(dataframe_penguins_numeric_discrete_data_scaled, kmeans.labels_)
    silhouettes.append(silhouette_coefficient)

    cluster_names = [f'cluster_{cluster}' for cluster in range(n_clusters_)]
    dataframe_penguins_numeric_discrete_data[f'clusters_{n_clusters_}'] = pd.Categorical.from_codes(kmeans.labels_, categories=cluster_names)

# %%
silhouette_dataframe = pd.DataFrame({'number_clusters': list(n_clusters), 'mean_silhouette': silhouettes})
silhouette_dataframe.plot.line(x = 'number_clusters', y = 'mean_silhouette', marker='o')
# Out:
# <Axes: xlabel='number_clusters'>

# %% [markdown]
# #### K-means

# %%
kmeans = KMeans(n_clusters=3, max_iter=600, n_init='auto', algorithm='lloyd')
kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)
# Out:
# KMeans(max_iter=600, n_clusters=3)

# %% [markdown]
# #### Cluster assign

# %%
dataframe_penguins_numeric_discrete_data['cluster_discrete_by_bin_scaled'] = kmeans.labels_.astype('str')

# %%
dataframe_penguins_numeric_discrete_data
# Out:
#      bill_length_mm_bin  bill_depth_mm_bin  flipper_length_mm_bin  \
# 0                  40.0               20.0                  180.0
# 1                  40.0               20.0                  190.0
# 2                  40.0               20.0                  200.0
# 3                  40.0               20.0                  190.0
# 6                  40.0               20.0                  200.0
# 7                  30.0               20.0                  190.0
# 11                 40.0               20.0                  180.0
# 13                 30.0               20.0                  200.0
# 16                 40.0               20.0                  200.0
# 17                 30.0               20.0                  180.0
# 18                 50.0               20.0                  190.0
# 19                 40.0               20.0                  170.0
# 38                 40.0               20.0                  180.0
# 44                 40.0               20.0                  190.0
# 69                 30.0               20.0                  190.0
# 72                 50.0               20.0                  200.0
# 94                 40.0               20.0                  210.0
# 110                50.0               20.0                  190.0
# 157                50.0               20.0                  180.0
# 163                50.0               20.0                  180.0
# 167                50.0               20.0                  200.0
# 168                60.0               20.0                  180.0
# 169                50.0               20.0                  190.0
# 180                50.0               20.0                  200.0
# 188                50.0               20.0                  210.0
# 191                50.0               20.0                  210.0
# 214                60.0               20.0                  210.0
# 219                50.0               10.0                  210.0
# 220                50.0               20.0                  230.0
# 222                50.0               20.0                  220.0
# 223                50.0               10.0                  220.0
# 224                50.0               10.0                  210.0
# 226                50.0               20.0                  220.0
# 227                40.0               10.0                  210.0
# 229                40.0               10.0                  210.0
# 232                50.0               10.0                  210.0
# 239                50.0               10.0                  220.0
# 243                40.0               10.0                  220.0
# 245                40.0               10.0                  220.0
# 252                60.0               20.0                  230.0
# 256                40.0               20.0                  220.0
# 310                50.0               20.0                  230.0
# 317                50.0               10.0                  200.0
# 328                50.0               20.0                  210.0
# 331                40.0               20.0                  210.0
# 333                50.0               10.0                  220.0
#
#      body_mass_g_bin clusters_2 clusters_3 clusters_4 clusters_5 clusters_6  \
# 0             4000.0  cluster_0  cluster_2  cluster_3  cluster_0  cluster_1
# 1             4000.0  cluster_0  cluster_2  cluster_3  cluster_0  cluster_1
# 2             3000.0  cluster_0  cluster_2  cluster_3  cluster_4  cluster_1
# 3             3000.0  cluster_0  cluster_2  cluster_3  cluster_4  cluster_1
# 6             5000.0  cluster_0  cluster_1  cluster_0  cluster_0  cluster_2
# 7             3000.0  cluster_0  cluster_2  cluster_3  cluster_0  cluster_1
# 11            3000.0  cluster_0  cluster_2  cluster_2  cluster_4  cluster_1
# 13            4000.0  cluster_0  cluster_2  cluster_3  cluster_0  cluster_1
# 16            4000.0  cluster_0  cluster_2  cluster_3  cluster_0  cluster_2
# 17            3000.0  cluster_0  cluster_2  cluster_3  cluster_0  cluster_1
# 18            4000.0  cluster_0  cluster_2  cluster_2  cluster_4  cluster_4
# 19            3000.0  cluster_0  cluster_2  cluster_2  cluster_4  cluster_1
# 38            5000.0  cluster_0  cluster_2  cluster_3  cluster_0  cluster_2
# 44            5000.0  cluster_0  cluster_1  cluster_3  cluster_0  cluster_2
# 69            4000.0  cluster_0  cluster_2  cluster_3  cluster_0  cluster_1
# 72            4000.0  cluster_0  cluster_2  cluster_2  cluster_4  cluster_4
# 94            4000.0  cluster_0  cluster_2  cluster_3  cluster_0  cluster_2
# 110           5000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_2
# 157           3000.0  cluster_0  cluster_2  cluster_2  cluster_4  cluster_4
# 163           4000.0  cluster_0  cluster_2  cluster_2  cluster_4  cluster_4
# 167           3000.0  cluster_0  cluster_2  cluster_2  cluster_4  cluster_4
# 168           4000.0  cluster_0  cluster_2  cluster_2  cluster_4  cluster_4
# 169           3000.0  cluster_0  cluster_2  cluster_2  cluster_4  cluster_4
# 180           5000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_2
# 188           5000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_2
# 191           4000.0  cluster_0  cluster_1  cluster_0  cluster_4  cluster_4
# 214           4000.0  cluster_0  cluster_1  cluster_0  cluster_4  cluster_4
# 219           4000.0  cluster_1  cluster_0  cluster_1  cluster_2  cluster_5
# 220           6000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_3
# 222           6000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_3
# 223           5000.0  cluster_1  cluster_0  cluster_1  cluster_1  cluster_0
# 224           5000.0  cluster_1  cluster_0  cluster_1  cluster_1  cluster_0
# 226           5000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_3
# 227           4000.0  cluster_1  cluster_0  cluster_1  cluster_2  cluster_5
# 229           5000.0  cluster_1  cluster_0  cluster_1  cluster_2  cluster_0
# 232           6000.0  cluster_1  cluster_0  cluster_1  cluster_1  cluster_0
# 239           6000.0  cluster_1  cluster_0  cluster_1  cluster_1  cluster_0
# 243           5000.0  cluster_1  cluster_0  cluster_1  cluster_2  cluster_5
# 245           4000.0  cluster_1  cluster_0  cluster_1  cluster_2  cluster_5
# 252           6000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_3
# 256           5000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_2
# 310           5000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_3
# 317           5000.0  cluster_1  cluster_0  cluster_1  cluster_1  cluster_0
# 328           6000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_3
# 331           5000.0  cluster_0  cluster_1  cluster_0  cluster_3  cluster_2
# 333           4000.0  cluster_1  cluster_0  cluster_1  cluster_2  cluster_5
#
#     clusters_7 clusters_8 clusters_9 clusters_10 clusters_11 clusters_12  \
# 0    cluster_6  cluster_4  cluster_2   cluster_6   cluster_2  cluster_10
# 1    cluster_3  cluster_4  cluster_2   cluster_6   cluster_9   cluster_8
# 2    cluster_6  cluster_3  cluster_6   cluster_0   cluster_2   cluster_8
# 3    cluster_6  cluster_3  cluster_6   cluster_0   cluster_2  cluster_10
# 6    cluster_3  cluster_5  cluster_0   cluster_4   cluster_7  cluster_11
# 7    cluster_5  cluster_3  cluster_6   cluster_0   cluster_9   cluster_0
# 11   cluster_6  cluster_3  cluster_6   cluster_0   cluster_2  cluster_10
# 13   cluster_5  cluster_4  cluster_2   cluster_6   cluster_9   cluster_0
# 16   cluster_3  cluster_4  cluster_2   cluster_6   cluster_0   cluster_8
# 17   cluster_5  cluster_3  cluster_6   cluster_0   cluster_2  cluster_10
# 18   cluster_1  cluster_5  cluster_5   cluster_8   cluster_5   cluster_1
# 19   cluster_6  cluster_3  cluster_6   cluster_0   cluster_2  cluster_10
# 38   cluster_3  cluster_5  cluster_0   cluster_4   cluster_7   cluster_5
# 44   cluster_3  cluster_5  cluster_0   cluster_4   cluster_7   cluster_5
# 69   cluster_5  cluster_4  cluster_2   cluster_6   cluster_9   cluster_0
# 72   cluster_1  cluster_5  cluster_7   cluster_2   cluster_5   cluster_1
# 94   cluster_3  cluster_4  cluster_2   cluster_6   cluster_0   cluster_8
# 110  cluster_1  cluster_5  cluster_0   cluster_4   cluster_5   cluster_5
# 157  cluster_6  cluster_2  cluster_6   cluster_8   cluster_8   cluster_3
# 163  cluster_1  cluster_5  cluster_5   cluster_8   cluster_8   cluster_3
# 167  cluster_6  cluster_2  cluster_7   cluster_8   cluster_8   cluster_3
# 168  cluster_1  cluster_2  cluster_5   cluster_7   cluster_4   cluster_9
# 169  cluster_6  cluster_2  cluster_6   cluster_8   cluster_8   cluster_3
# 180  cluster_4  cluster_7  cluster_3   cluster_9   cluster_5   cluster_6
# 188  cluster_4  cluster_7  cluster_3   cluster_9   cluster_5   cluster_6
# 191  cluster_4  cluster_7  cluster_7   cluster_2   cluster_5   cluster_1
# 214  cluster_4  cluster_7  cluster_7   cluster_2   cluster_5   cluster_1
# 219  cluster_2  cluster_1  cluster_1   cluster_5   cluster_6   cluster_7
# 220  cluster_0  cluster_0  cluster_8   cluster_3   cluster_3   cluster_4
# 222  cluster_0  cluster_0  cluster_8   cluster_3   cluster_3   cluster_4
# 223  cluster_2  cluster_6  cluster_4   cluster_1   cluster_1   cluster_2
# 224  cluster_2  cluster_6  cluster_4   cluster_1   cluster_1   cluster_2
# 226  cluster_4  cluster_7  cluster_3   cluster_9   cluster_3   cluster_6
# 227  cluster_2  cluster_1  cluster_1   cluster_5   cluster_6   cluster_7
# 229  cluster_2  cluster_6  cluster_4   cluster_5  cluster_10   cluster_7
# 232  cluster_2  cluster_6  cluster_4   cluster_1   cluster_1   cluster_2
# 239  cluster_2  cluster_6  cluster_4   cluster_1   cluster_1   cluster_2
# 243  cluster_2  cluster_1  cluster_4   cluster_5  cluster_10   cluster_7
# 245  cluster_2  cluster_1  cluster_1   cluster_5   cluster_6   cluster_7
# 252  cluster_0  cluster_0  cluster_8   cluster_3   cluster_3   cluster_4
# 256  cluster_3  cluster_7  cluster_3   cluster_9   cluster_0  cluster_11
# 310  cluster_4  cluster_0  cluster_3   cluster_9   cluster_3   cluster_6
# 317  cluster_2  cluster_6  cluster_4   cluster_1   cluster_1   cluster_2
# 328  cluster_0  cluster_0  cluster_3   cluster_9   cluster_3   cluster_4
# 331  cluster_3  cluster_7  cluster_0   cluster_4   cluster_0  cluster_11
# 333  cluster_2  cluster_1  cluster_1   cluster_5   cluster_6   cluster_7
#
#     clusters_13 clusters_14 clusters_15 cluster_discrete_by_bin_scaled
# 0     cluster_9   cluster_8   cluster_5                              0
# 1     cluster_4  cluster_13  cluster_12                              0
# 2    cluster_10   cluster_3  cluster_12                              0
# 3    cluster_10   cluster_3   cluster_2                              0
# 6    cluster_12   cluster_4   cluster_7                              2
# 7     cluster_3   cluster_5   cluster_2                              0
# 11   cluster_10   cluster_3   cluster_2                              0
# 13    cluster_4   cluster_5   cluster_6                              0
# 16    cluster_4  cluster_13  cluster_12                              0
# 17    cluster_3   cluster_3   cluster_2                              0
# 18    cluster_1   cluster_0   cluster_5                              0
# 19   cluster_10   cluster_3   cluster_2                              0
# 38    cluster_9   cluster_8   cluster_7                              0
# 44    cluster_9   cluster_8   cluster_7                              2
# 69    cluster_3   cluster_5   cluster_6                              0
# 72    cluster_1   cluster_0  cluster_10                              0
# 94    cluster_4  cluster_13  cluster_12                              0
# 110   cluster_1   cluster_0   cluster_0                              2
# 157   cluster_6  cluster_12   cluster_3                              0
# 163   cluster_1   cluster_0   cluster_5                              0
# 167   cluster_6  cluster_12   cluster_3                              0
# 168   cluster_1   cluster_0   cluster_5                              0
# 169   cluster_6  cluster_12   cluster_3                              0
# 180   cluster_2   cluster_2   cluster_0                              2
# 188   cluster_2   cluster_2   cluster_0                              2
# 191   cluster_2  cluster_10  cluster_10                              2
# 214   cluster_2  cluster_10  cluster_10                              2
# 219   cluster_7   cluster_9   cluster_9                              1
# 220   cluster_8   cluster_6  cluster_11                              2
# 222   cluster_8   cluster_6  cluster_11                              2
# 223   cluster_5   cluster_1   cluster_1                              1
# 224   cluster_5   cluster_1   cluster_9                              1
# 226   cluster_2   cluster_2   cluster_4                              2
# 227   cluster_7   cluster_9  cluster_13                              1
# 229   cluster_0   cluster_7   cluster_1                              1
# 232  cluster_11  cluster_11   cluster_8                              1
# 239  cluster_11  cluster_11   cluster_8                              1
# 243   cluster_0   cluster_7   cluster_1                              1
# 245   cluster_0   cluster_9  cluster_13                              1
# 252   cluster_8   cluster_6  cluster_11                              2
# 256  cluster_12   cluster_4  cluster_14                              2
# 310   cluster_2   cluster_2   cluster_4                              2
# 317   cluster_5   cluster_1   cluster_9                              1
# 328   cluster_8   cluster_6  cluster_11                              2
# 331  cluster_12   cluster_4  cluster_14                              2
# 333   cluster_7   cluster_9   cluster_9                              1

# %% [markdown]
# #### Assign sample cluster to data

# %%
dataframe_penguins = dataframe_penguins.merge(right=dataframe_penguins_numeric_discrete_data[['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin', 'cluster_discrete_by_bin_scaled']], on=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'], how='left')

# %% [markdown]
# #### Graph

# %%
dataframe_penguins_numeric_kmeans4 = dataframe_penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'cluster_discrete_by_bin_scaled']]

# %%
sns.pairplot(dataframe_penguins_numeric_kmeans4, hue='cluster_discrete_by_bin_scaled')

# %%
pd.crosstab(dataframe_penguins['species'], dataframe_penguins['cluster_discrete_by_bin_scaled'])
# Out:
# cluster_discrete_by_bin_scaled    0   1   2
# species
# Adelie                          145   0   6
# Chinstrap                        61   0   7
# Gentoo                            0  60  63
