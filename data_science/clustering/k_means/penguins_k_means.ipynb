# %% [markdown]
# ### Import

# %%
import numpy as np
import pandas as pd

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load

# %%
dataframe_penguins = sns.load_dataset('penguins')

# %% [markdown]
# ### Preview

# %%
dataframe_penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# dataframe_penguins.info()

# %%
dataframe_penguins.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
# dataframe_penguins.select_dtypes(include='number').columns.values

# %%
dataframe_penguins.dropna(subset=['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g'], inplace=True)

# %%
dataframe_penguins.isna().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  9
# dtype: int64

# %%
dataframe_penguins_numeric = dataframe_penguins.select_dtypes(include='number')
dataframe_penguins_numeric.head()
# Out:
#    bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0            39.1           18.7              181.0       3750.0
# 1            39.5           17.4              186.0       3800.0
# 2            40.3           18.0              195.0       3250.0
# 4            36.7           19.3              193.0       3450.0
# 5            39.3           20.6              190.0       3650.0

# %% [markdown]
# ### Centroids

# %%
rng = np.random.RandomState(seed=76)

n_centroids = 3
p_dimensions = len(dataframe_penguins_numeric.columns)

low = dataframe_penguins_numeric[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']].min().to_numpy()
high = dataframe_penguins_numeric[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']].max().to_numpy()

initial_centroids = rng.uniform(
    low=low, 
    high=high, 
    size=(n_centroids, p_dimensions)
)

initial_centroids
# Out:
# array([[  40.64781949,   19.97949265,  191.75040485, 3397.36866722],
#        [  35.13361644,   21.18340473,  223.03778785, 5768.68310607],
#        [  34.28655338,   19.49020666,  222.75140323, 3295.26441835]])

# %% [markdown]
# ### Common k-means

# %% [markdown]
# #### K-means

# %%
# %%time
kmeans = KMeans(n_clusters=n_centroids, max_iter=600, init=initial_centroids, n_init=1, algorithm='lloyd')
kmeans.fit(dataframe_penguins_numeric)
# Out:
# CPU times: user 37.3 ms, sys: 11.3 ms, total: 48.6 ms
# Wall time: 43.1 ms
# KMeans(init=array([[  40.64781949,   19.97949265,  191.75040485, 3397.36866722],
#        [  35.13361644,   21.18340473,  223.03778785, 5768.68310607],
#        [  34.28655338,   19.49020666,  222.75140323, 3295.26441835]]),
#        max_iter=600, n_clusters=3, n_init=1)

# %% [markdown]
# #### Cluster assign

# %%
dataframe_penguins['cluster_common'] = kmeans.labels_.astype('str')

# %% [markdown]
# #### Graph

# %%
dataframe_penguins_numeric_kmeans0 = dataframe_penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'cluster_common']]

# %%
sns.pairplot(dataframe_penguins_numeric_kmeans0, hue='cluster_common')

# %%
pd.crosstab(dataframe_penguins['species'], dataframe_penguins['cluster_common'])
# Out:
# cluster_common   0   1   2
# species
# Adelie          53   0  98
# Chinstrap       22   0  46
# Gentoo          42  81   0

# %% [markdown]
# ### Preclustering

# %% [markdown]
# #### Features

# %% [markdown]
# ##### _bin

# %% [markdown]
# bill_length_mm

# %%
ndigits = -1
dataframe_penguins['bill_length_mm_bin'] = round(dataframe_penguins['bill_length_mm'], ndigits=ndigits)

print(f"{dataframe_penguins['bill_length_mm'].head(3).values} \n{round(dataframe_penguins['bill_length_mm'], ndigits=ndigits).head(3).values}")
print(f"from {len(dataframe_penguins['bill_length_mm'].unique())} | to {len(dataframe_penguins['bill_length_mm_bin'].unique())}")
print(sorted(dataframe_penguins['bill_length_mm_bin'].unique()))
# Out:
# [39.1 39.5 40.3]
# [40. 40. 40.]
# from 164 | to 4
# [np.float64(30.0), np.float64(40.0), np.float64(50.0), np.float64(60.0)]

# %% [markdown]
# bill_depth_mm

# %%
ndigits = -1
dataframe_penguins['bill_depth_mm_bin'] = round(dataframe_penguins['bill_depth_mm'], ndigits=ndigits)

print(f"{dataframe_penguins['bill_depth_mm'].head(3).values} \n{round(dataframe_penguins['bill_depth_mm'], ndigits=ndigits).head(3).values}")
print(f"from {len(dataframe_penguins['bill_depth_mm'].unique())} | to {len(dataframe_penguins['bill_depth_mm_bin'].unique())}")
print(sorted(dataframe_penguins['bill_depth_mm_bin'].unique()))
# Out:
# [18.7 17.4 18. ]
# [20. 20. 20.]
# from 80 | to 2
# [np.float64(10.0), np.float64(20.0)]

# %% [markdown]
# flipper_length_mm

# %%
ndigits = -1
dataframe_penguins['flipper_length_mm_bin'] = round(dataframe_penguins['flipper_length_mm'], ndigits=ndigits)

print(f"{dataframe_penguins['flipper_length_mm'].head(3).values} \n{round(dataframe_penguins['flipper_length_mm'], ndigits=ndigits).head(3).values}")
print(f"from {len(dataframe_penguins['flipper_length_mm'].unique())} | to {len(dataframe_penguins['flipper_length_mm_bin'].unique())}")
print(sorted(dataframe_penguins['flipper_length_mm_bin'].unique()))
# Out:
# [181. 186. 195.]
# [180. 190. 200.]
# from 55 | to 7
# [np.float64(170.0), np.float64(180.0), np.float64(190.0), np.float64(200.0), np.float64(210.0), np.float64(220.0), np.float64(230.0)]

# %% [markdown]
# body_mass_g

# %%
ndigits = -3
dataframe_penguins['body_mass_g_bin'] = round(dataframe_penguins['body_mass_g'], ndigits=ndigits)

print(f"{dataframe_penguins['body_mass_g'].head(3).values} \n{round(dataframe_penguins['body_mass_g'], ndigits=ndigits).head(3).values}")
print(f"from {len(dataframe_penguins['body_mass_g'].unique())} | to {len(dataframe_penguins['body_mass_g_bin'].unique())}")
print(sorted(dataframe_penguins['body_mass_g_bin'].unique()))
# Out:
# [3750. 3800. 3250.]
# [4000. 4000. 3000.]
# from 94 | to 4
# [np.float64(3000.0), np.float64(4000.0), np.float64(5000.0), np.float64(6000.0)]

# %% [markdown]
# ##### _mean

# %%
dataframe_penguins[['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean']] = dataframe_penguins.groupby(by=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'])[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']].transform('mean')

# %% [markdown]
# #### Preclustering

# %% [markdown]
# ##### _bin

# %%
# dataframe_penguins['cluster_bin'] = (
#     dataframe_penguins['bill_length_mm_bin'].astype(str) + '_' + 
#     dataframe_penguins['bill_depth_mm_bin'].astype(str) + '_' + 
#     dataframe_penguins['flipper_length_mm_bin'].astype(str) + '_' + 
#     dataframe_penguins['body_mass_g_bin'].astype(str)
# )

# len(dataframe_penguins['cluster_bin'].unique())

# %%
# sns.pairplot(dataframe_penguins, hue='cluster_bin')

# %%
dataframe_penguins['cluster_bin'] = (
    dataframe_penguins.groupby(
        by=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'])
        .ngroup())

len(dataframe_penguins['cluster_bin'].unique())
# Out:
# 46

# %% [markdown]
# ##### _mean

# %%
# dataframe_penguins['cluster_mean'] = (
#     dataframe_penguins['bill_length_mm_bin_mean'].astype(str) + '_' + 
#     dataframe_penguins['bill_depth_mm_bin_mean'].astype(str) + '_' + 
#     dataframe_penguins['flipper_length_mm_bin_mean'].astype(str) + '_' + 
#     dataframe_penguins['body_mass_g_bin_mean'].astype(str)
# )

# len(dataframe_penguins['cluster_mean'].unique())

# %%
# sns.pairplot(dataframe_penguins, hue='cluster_mean')

# %%
dataframe_penguins['cluster_mean'] = (
    dataframe_penguins.groupby(
        by=['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean'])
        .ngroup())

len(dataframe_penguins['cluster_mean'].unique())
# Out:
# 46

# %% [markdown]
# ### K-means #1 | mean

# %% [markdown]
# - Utiliza a média das variáveis ('bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g') referente aos grupos criados no preclustring.
# - K-means aplicado a uma amostra.

# %% [markdown]
# #### Sample

# %%
dataframe_penguins_numeric_discrete_data = dataframe_penguins.drop_duplicates(subset=['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean'])[['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean']]

# %% [markdown]
# #### K-means

# %%
# %%time
kmeans = KMeans(n_clusters=n_centroids, max_iter=600, init=initial_centroids, n_init=1, algorithm='lloyd')
kmeans.fit(dataframe_penguins_numeric_discrete_data)
# Out:
# CPU times: user 7.69 ms, sys: 255 μs, total: 7.95 ms
# Wall time: 6.59 ms
# KMeans(init=array([[  40.64781949,   19.97949265,  191.75040485, 3397.36866722],
#        [  35.13361644,   21.18340473,  223.03778785, 5768.68310607],
#        [  34.28655338,   19.49020666,  222.75140323, 3295.26441835]]),
#        max_iter=600, n_clusters=3, n_init=1)

# %% [markdown]
# #### Cluster assign

# %%
dataframe_penguins_numeric_discrete_data['cluster_discrete_by_mean'] = kmeans.labels_.astype('str')

# %%
# dataframe_penguins_numeric_discrete_data

# %% [markdown]
# #### Assign sample cluster to data

# %%
dataframe_penguins = dataframe_penguins.merge(right=dataframe_penguins_numeric_discrete_data[['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean', 'cluster_discrete_by_mean']], on=['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean'], how='left')

# %%
# dataframe_penguins

# %% [markdown]
# #### Graph

# %%
dataframe_penguins_numeric_kmeans1 = dataframe_penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'cluster_discrete_by_mean']]

# %%
sns.pairplot(dataframe_penguins_numeric_kmeans1, hue='cluster_discrete_by_mean')

# %%
pd.crosstab(dataframe_penguins['species'], dataframe_penguins['cluster_discrete_by_mean'])
# Out:
# cluster_discrete_by_mean   0    1   2
# species
# Adelie                    89    7  55
# Chinstrap                 50    1  17
# Gentoo                    17  106   0

# %% [markdown]
# ### K-means #2 | bin

# %% [markdown]
# - Utiliza os valores arredondados (bins) das variáveis ('bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g') referente aos grupos criados no preclustring.
# - K-means aplicado a uma amostra.

# %% [markdown]
# #### Sample

# %%
dataframe_penguins_numeric_discrete_data = dataframe_penguins.drop_duplicates(subset=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'])[['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin']]

# %% [markdown]
# #### K-means

# %%
# %%time
kmeans = KMeans(n_clusters=n_centroids, max_iter=600, init=initial_centroids, n_init=1, algorithm='lloyd')
kmeans.fit(dataframe_penguins_numeric_discrete_data)
# Out:
# CPU times: user 5.09 ms, sys: 57 μs, total: 5.15 ms
# Wall time: 4.79 ms
# KMeans(init=array([[  40.64781949,   19.97949265,  191.75040485, 3397.36866722],
#        [  35.13361644,   21.18340473,  223.03778785, 5768.68310607],
#        [  34.28655338,   19.49020666,  222.75140323, 3295.26441835]]),
#        max_iter=600, n_clusters=3, n_init=1)

# %% [markdown]
# #### Cluster assign

# %%
dataframe_penguins_numeric_discrete_data['cluster_discrete_by_bin'] = kmeans.labels_.astype('str')

# %%
dataframe_penguins_numeric_discrete_data
# Out:
#      bill_length_mm_bin  bill_depth_mm_bin  flipper_length_mm_bin  \
# 0                  40.0               20.0                  180.0
# 1                  40.0               20.0                  190.0
# 2                  40.0               20.0                  200.0
# 3                  40.0               20.0                  190.0
# 6                  40.0               20.0                  200.0
# 7                  30.0               20.0                  190.0
# 11                 40.0               20.0                  180.0
# 13                 30.0               20.0                  200.0
# 16                 40.0               20.0                  200.0
# 17                 30.0               20.0                  180.0
# 18                 50.0               20.0                  190.0
# 19                 40.0               20.0                  170.0
# 38                 40.0               20.0                  180.0
# 44                 40.0               20.0                  190.0
# 69                 30.0               20.0                  190.0
# 72                 50.0               20.0                  200.0
# 94                 40.0               20.0                  210.0
# 110                50.0               20.0                  190.0
# 157                50.0               20.0                  180.0
# 163                50.0               20.0                  180.0
# 167                50.0               20.0                  200.0
# 168                60.0               20.0                  180.0
# 169                50.0               20.0                  190.0
# 180                50.0               20.0                  200.0
# 188                50.0               20.0                  210.0
# 191                50.0               20.0                  210.0
# 214                60.0               20.0                  210.0
# 219                50.0               10.0                  210.0
# 220                50.0               20.0                  230.0
# 222                50.0               20.0                  220.0
# 223                50.0               10.0                  220.0
# 224                50.0               10.0                  210.0
# 226                50.0               20.0                  220.0
# 227                40.0               10.0                  210.0
# 229                40.0               10.0                  210.0
# 232                50.0               10.0                  210.0
# 239                50.0               10.0                  220.0
# 243                40.0               10.0                  220.0
# 245                40.0               10.0                  220.0
# 252                60.0               20.0                  230.0
# 256                40.0               20.0                  220.0
# 310                50.0               20.0                  230.0
# 317                50.0               10.0                  200.0
# 328                50.0               20.0                  210.0
# 331                40.0               20.0                  210.0
# 333                50.0               10.0                  220.0
#
#      body_mass_g_bin cluster_discrete_by_bin
# 0             4000.0                       0
# 1             4000.0                       0
# 2             3000.0                       2
# 3             3000.0                       2
# 6             5000.0                       1
# 7             3000.0                       2
# 11            3000.0                       2
# 13            4000.0                       0
# 16            4000.0                       0
# 17            3000.0                       2
# 18            4000.0                       0
# 19            3000.0                       2
# 38            5000.0                       1
# 44            5000.0                       1
# 69            4000.0                       0
# 72            4000.0                       0
# 94            4000.0                       0
# 110           5000.0                       1
# 157           3000.0                       2
# 163           4000.0                       0
# 167           3000.0                       2
# 168           4000.0                       0
# 169           3000.0                       2
# 180           5000.0                       1
# 188           5000.0                       1
# 191           4000.0                       0
# 214           4000.0                       0
# 219           4000.0                       0
# 220           6000.0                       1
# 222           6000.0                       1
# 223           5000.0                       1
# 224           5000.0                       1
# 226           5000.0                       1
# 227           4000.0                       0
# 229           5000.0                       1
# 232           6000.0                       1
# 239           6000.0                       1
# 243           5000.0                       1
# 245           4000.0                       0
# 252           6000.0                       1
# 256           5000.0                       1
# 310           5000.0                       1
# 317           5000.0                       1
# 328           6000.0                       1
# 331           5000.0                       1
# 333           4000.0                       0

# %% [markdown]
# #### Assign sample cluster to data

# %%
dataframe_penguins = dataframe_penguins.merge(right=dataframe_penguins_numeric_discrete_data[['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin', 'cluster_discrete_by_bin']], on=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'], how='left')

# %% [markdown]
# #### Graph

# %%
dataframe_penguins_numeric_kmeans2 = dataframe_penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'cluster_discrete_by_bin']]

# %%
sns.pairplot(dataframe_penguins_numeric_kmeans2, hue='cluster_discrete_by_bin')

# %%
pd.crosstab(dataframe_penguins['species'], dataframe_penguins['cluster_discrete_by_bin'])
# Out:
# cluster_discrete_by_bin   0    1   2
# species
# Adelie                   90    7  54
# Chinstrap                49    2  17
# Gentoo                   17  106   0

# %% [markdown]
# ### K-means #3 | mean scaled

# %% [markdown]
# - Utiliza a média das variáveis redimensionadas ('bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g') referente aos grupos criados no preclustring.
# - K-means aplicado a uma amostra.

# %% [markdown]
# #### Sample

# %%
dataframe_penguins_numeric_discrete_data = dataframe_penguins.drop_duplicates(subset=['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean'])[['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean']]

# %% [markdown]
# #### Data scaling

# %%
scaler = StandardScaler()
# scaler = MinMaxScaler()

dataframe_penguins_numeric_discrete_data_scaled = scaler.fit_transform(dataframe_penguins_numeric_discrete_data)

# %% [markdown]
# #### Elbow method

# %%
ssd = []
n_clusters = range(1, 15)

for n_clusters_ in n_clusters:
    kmeans = KMeans(n_clusters=n_clusters_, max_iter=600, n_init='auto', algorithm='lloyd')
    kmeans = kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)
    ssd.append(kmeans.inertia_)

# %%
elbow_dataframe = pd.DataFrame({'n_clusters': list(range(1, len(ssd) + 1)), 'SSD': ssd})
elbow_dataframe.plot(x = 'n_clusters', y = 'SSD')
# Out:
# <Axes: xlabel='n_clusters'>

# %% [markdown]
# #### Silhouette coefficient

# %%
silhouettes = []
max_clusters = 15
n_clusters = range(2, max_clusters + 1)

for n_clusters_ in n_clusters:
    kmeans = KMeans(n_clusters=n_clusters_, max_iter=600, n_init='auto', algorithm='lloyd')
    kmeans = kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)

    silhouette_coefficient = silhouette_score(dataframe_penguins_numeric_discrete_data_scaled, kmeans.labels_)
    silhouettes.append(silhouette_coefficient)

    cluster_names = [f'cluster_{cluster}' for cluster in range(n_clusters_)]
    dataframe_penguins_numeric_discrete_data[f'clusters_{n_clusters_}'] = pd.Categorical.from_codes(kmeans.labels_, categories=cluster_names)

# %%
silhouette_dataframe = pd.DataFrame({'number_clusters': list(n_clusters), 'mean_silhouette': silhouettes})
silhouette_dataframe.plot.line(x = 'number_clusters', y = 'mean_silhouette', marker='o')
# Out:
# <Axes: xlabel='number_clusters'>

# %% [markdown]
# #### K-means

# %%
# %%time
kmeans = KMeans(n_clusters=n_centroids, max_iter=600, init=initial_centroids, n_init=1, algorithm='lloyd')
kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)
# Out:
# CPU times: user 7.52 ms, sys: 0 ns, total: 7.52 ms
# Wall time: 6.2 ms
# KMeans(init=array([[  40.64781949,   19.97949265,  191.75040485, 3397.36866722],
#        [  35.13361644,   21.18340473,  223.03778785, 5768.68310607],
#        [  34.28655338,   19.49020666,  222.75140323, 3295.26441835]]),
#        max_iter=600, n_clusters=3, n_init=1)

# %% [markdown]
# #### Cluster assign

# %%
dataframe_penguins_numeric_discrete_data['cluster_discrete_by_mean_scaled'] = kmeans.labels_.astype('str')

# %%
# dataframe_penguins_numeric_discrete_data

# %% [markdown]
# #### Assign sample cluster to data

# %%
dataframe_penguins = dataframe_penguins.merge(right=dataframe_penguins_numeric_discrete_data[['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean', 'cluster_discrete_by_mean_scaled']], on=['bill_length_mm_bin_mean', 'bill_depth_mm_bin_mean', 'flipper_length_mm_bin_mean', 'body_mass_g_bin_mean'], how='left')

# %% [markdown]
# #### Graph

# %%
dataframe_penguins_numeric_kmeans3 = dataframe_penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'cluster_discrete_by_mean_scaled']]

# %%
sns.pairplot(dataframe_penguins_numeric_kmeans3, hue='cluster_discrete_by_mean_scaled')

# %%
pd.crosstab(dataframe_penguins['species'], dataframe_penguins['cluster_discrete_by_mean_scaled'])
# Out:
# cluster_discrete_by_mean_scaled    0   1    2
# species
# Adelie                           148   3    0
# Chinstrap                          6  61    1
# Gentoo                             0   0  123

# %% [markdown]
# ### K-means #4 | bin scaled

# %% [markdown]
# - Utiliza os valores arredondados (bins) das variáveis redimensionados ('bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g') referente aos grupos criados no preclustring.
# - K-means aplicado a uma amostra.

# %% [markdown]
# #### Sample

# %%
dataframe_penguins_numeric_discrete_data = dataframe_penguins.drop_duplicates(subset=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'])[['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin']]

# %% [markdown]
# #### Data scaling

# %%
# scaler = StandardScaler()
scaler = MinMaxScaler()

dataframe_penguins_numeric_discrete_data_scaled = scaler.fit_transform(dataframe_penguins_numeric_discrete_data)

# %% [markdown]
# #### Elbow method

# %%
ssd = []
n_clusters = range(1, 15)

for n_clusters_ in n_clusters:
    kmeans = KMeans(n_clusters=n_clusters_, max_iter=600, n_init='auto', algorithm='lloyd')
    kmeans = kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)
    ssd.append(kmeans.inertia_)

# %%
elbow_dataframe = pd.DataFrame({'n_clusters': list(range(1, len(ssd) + 1)), 'SSD': ssd})
elbow_dataframe.plot(x = 'n_clusters', y = 'SSD')
# Out:
# <Axes: xlabel='n_clusters'>

# %% [markdown]
# #### Silhouette coefficient

# %%
silhouettes = []
max_clusters = 15
n_clusters = range(2, max_clusters + 1)

for n_clusters_ in n_clusters:
    kmeans = KMeans(n_clusters=n_clusters_, max_iter=600, n_init='auto', algorithm='lloyd')
    kmeans = kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)

    silhouette_coefficient = silhouette_score(dataframe_penguins_numeric_discrete_data_scaled, kmeans.labels_)
    silhouettes.append(silhouette_coefficient)

    cluster_names = [f'cluster_{cluster}' for cluster in range(n_clusters_)]
    dataframe_penguins_numeric_discrete_data[f'clusters_{n_clusters_}'] = pd.Categorical.from_codes(kmeans.labels_, categories=cluster_names)

# %%
silhouette_dataframe = pd.DataFrame({'number_clusters': list(n_clusters), 'mean_silhouette': silhouettes})
silhouette_dataframe.plot.line(x = 'number_clusters', y = 'mean_silhouette', marker='o')
# Out:
# <Axes: xlabel='number_clusters'>

# %% [markdown]
# #### K-means

# %%
# %%time
kmeans = KMeans(n_clusters=n_centroids, max_iter=600, init=initial_centroids, n_init=1, algorithm='lloyd')
kmeans.fit(dataframe_penguins_numeric_discrete_data_scaled)
# Out:
# CPU times: user 7.59 ms, sys: 0 ns, total: 7.59 ms
# Wall time: 5.46 ms
# KMeans(init=array([[  40.64781949,   19.97949265,  191.75040485, 3397.36866722],
#        [  35.13361644,   21.18340473,  223.03778785, 5768.68310607],
#        [  34.28655338,   19.49020666,  222.75140323, 3295.26441835]]),
#        max_iter=600, n_clusters=3, n_init=1)

# %% [markdown]
# #### Cluster assign

# %%
dataframe_penguins_numeric_discrete_data['cluster_discrete_by_bin_scaled'] = kmeans.labels_.astype('str')

# %%
dataframe_penguins_numeric_discrete_data
# Out:
#      bill_length_mm_bin  bill_depth_mm_bin  flipper_length_mm_bin  \
# 0                  40.0               20.0                  180.0
# 1                  40.0               20.0                  190.0
# 2                  40.0               20.0                  200.0
# 3                  40.0               20.0                  190.0
# 6                  40.0               20.0                  200.0
# 7                  30.0               20.0                  190.0
# 11                 40.0               20.0                  180.0
# 13                 30.0               20.0                  200.0
# 16                 40.0               20.0                  200.0
# 17                 30.0               20.0                  180.0
# 18                 50.0               20.0                  190.0
# 19                 40.0               20.0                  170.0
# 38                 40.0               20.0                  180.0
# 44                 40.0               20.0                  190.0
# 69                 30.0               20.0                  190.0
# 72                 50.0               20.0                  200.0
# 94                 40.0               20.0                  210.0
# 110                50.0               20.0                  190.0
# 157                50.0               20.0                  180.0
# 163                50.0               20.0                  180.0
# 167                50.0               20.0                  200.0
# 168                60.0               20.0                  180.0
# 169                50.0               20.0                  190.0
# 180                50.0               20.0                  200.0
# 188                50.0               20.0                  210.0
# 191                50.0               20.0                  210.0
# 214                60.0               20.0                  210.0
# 219                50.0               10.0                  210.0
# 220                50.0               20.0                  230.0
# 222                50.0               20.0                  220.0
# 223                50.0               10.0                  220.0
# 224                50.0               10.0                  210.0
# 226                50.0               20.0                  220.0
# 227                40.0               10.0                  210.0
# 229                40.0               10.0                  210.0
# 232                50.0               10.0                  210.0
# 239                50.0               10.0                  220.0
# 243                40.0               10.0                  220.0
# 245                40.0               10.0                  220.0
# 252                60.0               20.0                  230.0
# 256                40.0               20.0                  220.0
# 310                50.0               20.0                  230.0
# 317                50.0               10.0                  200.0
# 328                50.0               20.0                  210.0
# 331                40.0               20.0                  210.0
# 333                50.0               10.0                  220.0
#
#      body_mass_g_bin clusters_2 clusters_3 clusters_4 clusters_5 clusters_6  \
# 0             4000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_0
# 1             4000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_0
# 2             3000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_0
# 3             3000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_0
# 6             5000.0  cluster_0  cluster_2  cluster_3  cluster_1  cluster_4
# 7             3000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_0
# 11            3000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_0
# 13            4000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_0
# 16            4000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_4
# 17            3000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_0
# 18            4000.0  cluster_0  cluster_0  cluster_3  cluster_4  cluster_3
# 19            3000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_0
# 38            5000.0  cluster_0  cluster_0  cluster_3  cluster_1  cluster_4
# 44            5000.0  cluster_0  cluster_0  cluster_3  cluster_1  cluster_4
# 69            4000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_0
# 72            4000.0  cluster_0  cluster_0  cluster_3  cluster_4  cluster_3
# 94            4000.0  cluster_0  cluster_0  cluster_0  cluster_3  cluster_4
# 110           5000.0  cluster_0  cluster_2  cluster_3  cluster_1  cluster_4
# 157           3000.0  cluster_0  cluster_0  cluster_0  cluster_4  cluster_3
# 163           4000.0  cluster_0  cluster_0  cluster_3  cluster_4  cluster_3
# 167           3000.0  cluster_0  cluster_0  cluster_0  cluster_4  cluster_3
# 168           4000.0  cluster_0  cluster_0  cluster_3  cluster_4  cluster_3
# 169           3000.0  cluster_0  cluster_0  cluster_0  cluster_4  cluster_3
# 180           5000.0  cluster_0  cluster_2  cluster_3  cluster_1  cluster_4
# 188           5000.0  cluster_0  cluster_2  cluster_2  cluster_2  cluster_2
# 191           4000.0  cluster_0  cluster_2  cluster_3  cluster_4  cluster_3
# 214           4000.0  cluster_0  cluster_2  cluster_3  cluster_4  cluster_3
# 219           4000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_5
# 220           6000.0  cluster_0  cluster_2  cluster_2  cluster_2  cluster_2
# 222           6000.0  cluster_0  cluster_2  cluster_2  cluster_2  cluster_2
# 223           5000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_1
# 224           5000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_1
# 226           5000.0  cluster_0  cluster_2  cluster_2  cluster_2  cluster_2
# 227           4000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_5
# 229           5000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_5
# 232           6000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_1
# 239           6000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_1
# 243           5000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_5
# 245           4000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_5
# 252           6000.0  cluster_0  cluster_2  cluster_2  cluster_2  cluster_2
# 256           5000.0  cluster_0  cluster_2  cluster_2  cluster_2  cluster_4
# 310           5000.0  cluster_0  cluster_2  cluster_2  cluster_2  cluster_2
# 317           5000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_1
# 328           6000.0  cluster_0  cluster_2  cluster_2  cluster_2  cluster_2
# 331           5000.0  cluster_0  cluster_2  cluster_2  cluster_1  cluster_4
# 333           4000.0  cluster_1  cluster_1  cluster_1  cluster_0  cluster_5
#
#     clusters_7 clusters_8 clusters_9 clusters_10 clusters_11 clusters_12  \
# 0    cluster_1  cluster_4  cluster_6   cluster_7  cluster_10   cluster_2
# 1    cluster_1  cluster_4  cluster_0   cluster_7  cluster_10   cluster_2
# 2    cluster_4  cluster_3  cluster_3   cluster_2   cluster_6   cluster_2
# 3    cluster_4  cluster_3  cluster_7   cluster_2   cluster_6   cluster_5
# 6    cluster_1  cluster_4  cluster_6   cluster_7   cluster_1   cluster_7
# 7    cluster_4  cluster_3  cluster_7   cluster_6   cluster_4   cluster_5
# 11   cluster_4  cluster_3  cluster_7   cluster_2   cluster_0   cluster_5
# 13   cluster_1  cluster_4  cluster_0   cluster_6   cluster_4   cluster_2
# 16   cluster_1  cluster_4  cluster_0   cluster_1   cluster_6   cluster_2
# 17   cluster_4  cluster_3  cluster_7   cluster_6   cluster_0   cluster_5
# 18   cluster_3  cluster_7  cluster_4   cluster_8   cluster_9  cluster_11
# 19   cluster_4  cluster_3  cluster_7   cluster_2   cluster_0   cluster_5
# 38   cluster_1  cluster_4  cluster_6   cluster_7  cluster_10   cluster_7
# 44   cluster_1  cluster_4  cluster_6   cluster_7  cluster_10   cluster_7
# 69   cluster_1  cluster_4  cluster_0   cluster_6   cluster_4   cluster_2
# 72   cluster_3  cluster_6  cluster_4   cluster_1   cluster_9  cluster_11
# 94   cluster_1  cluster_4  cluster_0   cluster_1   cluster_1   cluster_2
# 110  cluster_2  cluster_4  cluster_4   cluster_7   cluster_3   cluster_7
# 157  cluster_3  cluster_7  cluster_3   cluster_9   cluster_9   cluster_4
# 163  cluster_3  cluster_7  cluster_4   cluster_8   cluster_9   cluster_4
# 167  cluster_3  cluster_6  cluster_3   cluster_9   cluster_6  cluster_11
# 168  cluster_3  cluster_7  cluster_4   cluster_8   cluster_9   cluster_4
# 169  cluster_3  cluster_7  cluster_3   cluster_9   cluster_9   cluster_4
# 180  cluster_2  cluster_1  cluster_4   cluster_5   cluster_3   cluster_3
# 188  cluster_2  cluster_1  cluster_2   cluster_5   cluster_7   cluster_3
# 191  cluster_2  cluster_6  cluster_4   cluster_1   cluster_7  cluster_11
# 214  cluster_2  cluster_6  cluster_4   cluster_1   cluster_7   cluster_0
# 219  cluster_0  cluster_5  cluster_5   cluster_0   cluster_8   cluster_6
# 220  cluster_6  cluster_0  cluster_8   cluster_4   cluster_5   cluster_9
# 222  cluster_6  cluster_0  cluster_8   cluster_4   cluster_5   cluster_9
# 223  cluster_5  cluster_5  cluster_1   cluster_3   cluster_2   cluster_8
# 224  cluster_5  cluster_5  cluster_1   cluster_3   cluster_2   cluster_8
# 226  cluster_2  cluster_1  cluster_2   cluster_5   cluster_7   cluster_3
# 227  cluster_0  cluster_2  cluster_5   cluster_0   cluster_8   cluster_1
# 229  cluster_5  cluster_2  cluster_5   cluster_3   cluster_2   cluster_8
# 232  cluster_5  cluster_5  cluster_1   cluster_3   cluster_2  cluster_10
# 239  cluster_5  cluster_5  cluster_1   cluster_3   cluster_2  cluster_10
# 243  cluster_5  cluster_2  cluster_5   cluster_3   cluster_2   cluster_8
# 245  cluster_0  cluster_2  cluster_5   cluster_0   cluster_8   cluster_1
# 252  cluster_6  cluster_0  cluster_8   cluster_4   cluster_5   cluster_9
# 256  cluster_2  cluster_1  cluster_2   cluster_5   cluster_1   cluster_3
# 310  cluster_2  cluster_1  cluster_2   cluster_5   cluster_7   cluster_3
# 317  cluster_5  cluster_5  cluster_1   cluster_3   cluster_2   cluster_8
# 328  cluster_6  cluster_0  cluster_8   cluster_4   cluster_5   cluster_9
# 331  cluster_2  cluster_1  cluster_2   cluster_5   cluster_1   cluster_7
# 333  cluster_0  cluster_5  cluster_5   cluster_0   cluster_8   cluster_6
#
#     clusters_13 clusters_14 clusters_15 cluster_discrete_by_bin_scaled
# 0     cluster_1   cluster_5  cluster_14                              1
# 1     cluster_1   cluster_5  cluster_14                              1
# 2     cluster_6   cluster_3  cluster_11                              1
# 3     cluster_9   cluster_3  cluster_11                              1
# 6     cluster_7   cluster_4   cluster_4                              0
# 7     cluster_3   cluster_6   cluster_9                              1
# 11    cluster_9   cluster_7   cluster_2                              1
# 13    cluster_1   cluster_6   cluster_9                              1
# 16    cluster_1   cluster_5  cluster_14                              1
# 17    cluster_3   cluster_6   cluster_9                              1
# 18    cluster_5   cluster_1   cluster_7                              1
# 19    cluster_9   cluster_7   cluster_2                              1
# 38   cluster_12   cluster_4   cluster_4                              1
# 44   cluster_12   cluster_4   cluster_4                              0
# 69    cluster_1   cluster_6   cluster_9                              1
# 72    cluster_5   cluster_1   cluster_8                              1
# 94    cluster_1   cluster_5  cluster_14                              1
# 110   cluster_0  cluster_11   cluster_1                              0
# 157   cluster_6  cluster_10  cluster_13                              1
# 163   cluster_5   cluster_9   cluster_7                              1
# 167   cluster_6  cluster_10  cluster_13                              1
# 168   cluster_5   cluster_9   cluster_7                              1
# 169   cluster_6  cluster_10  cluster_13                              1
# 180   cluster_0  cluster_11   cluster_1                              0
# 188   cluster_0  cluster_11  cluster_12                              0
# 191  cluster_10   cluster_1   cluster_8                              0
# 214  cluster_10   cluster_1   cluster_8                              0
# 219  cluster_11   cluster_8  cluster_10                              2
# 220   cluster_4   cluster_2   cluster_6                              0
# 222   cluster_4   cluster_2   cluster_6                              0
# 223   cluster_2   cluster_0   cluster_3                              2
# 224   cluster_2   cluster_0   cluster_3                              2
# 226   cluster_0  cluster_11  cluster_12                              0
# 227   cluster_8  cluster_13  cluster_10                              2
# 229   cluster_8  cluster_13   cluster_3                              2
# 232   cluster_2  cluster_12   cluster_0                              2
# 239   cluster_2  cluster_12   cluster_0                              2
# 243   cluster_8  cluster_13   cluster_3                              2
# 245   cluster_8  cluster_13  cluster_10                              2
# 252   cluster_4   cluster_2   cluster_6                              0
# 256   cluster_7   cluster_4   cluster_5                              0
# 310   cluster_4   cluster_2  cluster_12                              0
# 317   cluster_2   cluster_0   cluster_3                              2
# 328   cluster_4   cluster_2   cluster_6                              0
# 331   cluster_7   cluster_4   cluster_5                              0
# 333  cluster_11   cluster_8  cluster_10                              2

# %% [markdown]
# #### Assign sample cluster to data

# %%
dataframe_penguins = dataframe_penguins.merge(right=dataframe_penguins_numeric_discrete_data[['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin', 'cluster_discrete_by_bin_scaled']], on=['bill_length_mm_bin', 'bill_depth_mm_bin', 'flipper_length_mm_bin', 'body_mass_g_bin'], how='left')

# %% [markdown]
# #### Graph

# %%
dataframe_penguins_numeric_kmeans4 = dataframe_penguins[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'cluster_discrete_by_bin_scaled']]

# %%
sns.pairplot(dataframe_penguins_numeric_kmeans4, hue='cluster_discrete_by_bin_scaled')

# %%
pd.crosstab(dataframe_penguins['species'], dataframe_penguins['cluster_discrete_by_bin_scaled'])
# Out:
# cluster_discrete_by_bin_scaled   0    1   2
# species
# Adelie                           6  145   0
# Chinstrap                        7   61   0
# Gentoo                          63    0  60

# %%
dataframe_penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 337  Gentoo     Biscoe            47.2           13.7              214.0
# 338  Gentoo     Biscoe            46.8           14.3              215.0
# 339  Gentoo     Biscoe            50.4           15.7              222.0
# 340  Gentoo     Biscoe            45.2           14.8              212.0
# 341  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex cluster_common  bill_length_mm_bin  \
# 0         3750.0    Male              2                40.0
# 1         3800.0  Female              2                40.0
# 2         3250.0  Female              2                40.0
# 3         3450.0  Female              2                40.0
# 4         3650.0    Male              2                40.0
# ..           ...     ...            ...                 ...
# 337       4925.0  Female              1                50.0
# 338       4850.0  Female              1                50.0
# 339       5750.0    Male              1                50.0
# 340       5200.0  Female              1                50.0
# 341       5400.0    Male              1                50.0
#
#      bill_depth_mm_bin  ...  bill_length_mm_bin_mean  bill_depth_mm_bin_mean  \
# 0                 20.0  ...                39.082353               18.229412
# 1                 20.0  ...                38.866667               18.726190
# 2                 20.0  ...                38.400000               17.683333
# 3                 20.0  ...                38.362069               17.451724
# 4                 20.0  ...                38.866667               18.726190
# ..                 ...  ...                      ...                     ...
# 337               10.0  ...                46.606667               14.266667
# 338               10.0  ...                47.138462               14.376923
# 339               20.0  ...                49.511765               15.723529
# 340               10.0  ...                46.606667               14.266667
# 341               20.0  ...                50.200000               17.500000
#
#      flipper_length_mm_bin_mean  body_mass_g_bin_mean  cluster_bin  \
# 0                    182.117647           3722.058824           10
# 1                    190.023810           3863.095238           13
# 2                    196.166667           3370.833333           15
# 3                    189.068966           3233.620690           12
# 4                    190.023810           3863.095238           13
# ..                          ...                   ...          ...
# 337                  211.200000           4776.666667           23
# 338                  217.692308           5034.615385           26
# 339                  220.352941           5723.529412           40
# 340                  211.200000           4776.666667           23
# 341                  210.333333           5183.333333           37
#
#      cluster_mean  cluster_discrete_by_mean  cluster_discrete_by_bin  \
# 0               9                         0                        0
# 1               8                         0                        0
# 2               7                         2                        2
# 3               6                         2                        2
# 4               8                         0                        0
# ..            ...                       ...                      ...
# 337            25                         1                        1
# 338            27                         1                        1
# 339            34                         1                        1
# 340            25                         1                        1
# 341            38                         1                        1
#
#     cluster_discrete_by_mean_scaled cluster_discrete_by_bin_scaled
# 0                                 0                              1
# 1                                 0                              1
# 2                                 0                              1
# 3                                 0                              1
# 4                                 0                              1
# ..                              ...                            ...
# 337                               2                              2
# 338                               2                              2
# 339                               2                              0
# 340                               2                              2
# 341                               2                              0
#
# [342 rows x 22 columns]
